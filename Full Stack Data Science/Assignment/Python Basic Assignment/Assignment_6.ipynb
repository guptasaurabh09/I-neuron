# %%
1. What are escape characters, and how do you use them?

\ is the escape character
it is use represent \t tab \n newline

# %%
2. What do the escape characters n and t stand for?

\n stand for nextline
\t stand for tab or space

# %%
print('apple\nball')
print('apple\tball')
# Out:
# apple
# ball
# apple	ball

# %%
3. What is the way to include backslash characters in a string?

# %%
print('\\')
# Out:
# \

# %%
4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?

' is not a problem because it is inside a sting

# %%
print("Howl's Moving Castle" )
# Out:
# Howl's Moving Castle

# %%
5. How do you write a string of newlines if you don't want to use the n character?

we can use os.linesep togo to new line

# %%
import os
print('apple'+os.linesep+'ball')
# Out:
# apple
# ball

# %%
6. What are the values of the given expressions?

# %%
'Hello, world!'[1] #returning letter at index 1
# Out:
# 'e'

# %%
'Hello, world!'[0:5] #returning 1st 5 letter
# Out:
# 'Hello'

# %%
'Hello, world!'[:5]  #returning 1st 5 letter
# Out:
# 'Hello'

# %%
'Hello, world!'[3:]  #returning letters after 3rd
# Out:
# 'lo, world!'

# %%
7. What are the values of the following expressions?

# %%
'Hello'.upper() #convert all letter to upper case
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper() #convert all letter to upper case and checking if they are in upper case
# Out:
# True

# %%
'Hello'.upper().lower()  #convert all letter to upper case and again convert them into lower case
# Out:
# 'hello'

# %%
8. What are the values of the following expressions?

# %%
'Remember, remember, the fifth of July.'.split()A # will split them on base of space
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']

# %%
'-'.join('There can only one.'.split()) # will split them on base of space and join them back on with -
# Out:
# 'There-can-only-one.'

# %%
9. What are the methods for right-justifying, left-justifying, and centering a string?

# %%
print ('apple'.rjust(40, '-'))
print ('apple'.ljust(40, '-'))
print ('apple'.center(40, '-'))
# Out:
# -----------------------------------apple
# apple-----------------------------------
# -----------------apple------------------

# %%
10. What is the best way to remove whitespace characters from the start or end?

# %%
str1='   Hello world   '

str2=' '.join( str1.split())

# %%
print(str2+ ' length of str1 is '+str(len(str1))+' length of str2 is '+str(len(str2)))
# Out:
# Hello world length of str1 is 17 length of str2 is 11
