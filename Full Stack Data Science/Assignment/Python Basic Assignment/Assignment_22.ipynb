# %%
1. What is the result of the code, and explain?

X = 'iNeuron'
def func():
    print(X)

func()


Calling a function and printing value of X inside the function

# %%
X = 'iNeuron'
def func():
    print(X)

func()
# Out:
# iNeuron

# %%
2. What is the result of the code, and explain?


X = 'iNeuron'
def func():
    X = 'NI!'


func()
print(X)


Calling function  and assigning a local value to X inside a function and checking value outside the fun

# %%
X = 'iNeuron'
def func():
    X = 'NI!'


func()
print(X)
# Out:
# iNeuron

# %%
3. What does this code print, and why?


X = 'iNeuron'
def func():
    X = 'NI'
    print(X)


func()
print(X)

Calling function  and assigning a local value to X inside a function
and printing it inside function and checking value outside the fun

# %%
X = 'iNeuron'
def func():
    X = 'NI'
    print(X)


func()
print(X)
# Out:
# NI
# iNeuron

# %%
4. What output does this code produce? Why?


X = 'iNeuron'
def func():
    global X
    X = 'NI'

func()
print(X)


Calling function  and declaring gloabl to X and assigning a  value to X inside a function 
 and checking value outside the fun

# %%
X = 'iNeuron'
def func():
    global X
    X = 'NI'

func()
print(X)
# Out:
# NI

# %%
5. What about this code—what’s the output, and why?

X = 'iNeuron'
def func():
    X = 'NI'
    def nested():
        print(X)
    nested()


func()
X


We have created a function nested inside a function func and nested is called inside func 
nested is printing local value of X and X outside func is printing global value of X

# %%
X = 'iNeuron'
def func():
    X = 'NI'
    def nested():
        print(X)
    nested()


func()
X
# Out:
# NI
# 'iNeuron'

# %%
6. How about this code: what is its output in Python 3, and explain?


def func():
    X = 'NI'
    def nested():
        nonlocal X
        X = 'Spam'
    nested()
    print(X)
    

func()


We have created a function nested inside a function func and nested is called inside func 
nested is printing value value of X, X is declare non local inside nested so that Spam should be print instead of NI

# %%
def func():
    X = 'NI'
    def nested():
        nonlocal X
        X = 'Spam'
    nested()
    print(X)
    

func()
# Out:
# Spam
