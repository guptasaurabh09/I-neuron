# %%
1. What does an empty dictionary's code look like?

# %%
d={}

# %%
2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %%
d={'a':42}

# %%
3. What is the most significant distinction between a dictionary and a list?

dictionary as key value list only has values

# %%
4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %%
spam={'bar': 100}
spam['bar']
# Out:
# 100

# %%
5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

spam['cat'] will return value related to key 'cat' spam.keys() will give list of all the keys in dictionary

# %%
spam={'cat': 100}
spam['cat']
# Out:
# 100

# %%
spam.keys()
# Out:
# dict_keys(['cat'])

# %%
6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

spam['cat'] will return value related to key 'cat' spam.keys() will give list of all the values in dictionary

# %%
spam.values()
# Out:
# dict_values([100])

# %%
7. What is a shortcut for the following code?
if 'color' not in spam:
    spam['color'] = 'black'

setdefault('','') can be used it has 2 parameter 1st one is key and 2ns is value if key that we pass is not present 
it will set it by default

# %%
spam.setdefault('color', 'black')
# Out:
# 'black'

# %%
8. How do you "pretty print" dictionary values using which module and function?

pprint is used to pretty print dictionary values

# %%
import pprint
pprint.pprint(spam.values())
# Out:
# dict_values([100, 'black'])

# %%
print(pprint.pformat(spam.values()))
# Out:
# dict_values([100, 'black'])
