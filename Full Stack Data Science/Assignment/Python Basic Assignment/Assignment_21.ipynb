# %%
1. Add the current date to the text file today.txt as a string.

# %%
from datetime import date
today = date.today()

f = open("today.txt", "w")
f.write(str(today))
f.close()

# %%
2. Read the text file today.txt into the string today_string

# %%
f = open("today.txt", "r")
print(f.read())
with open('today.txt') as f:
    today_string = f.read()
# Out:
# 2021-08-08

# %%
3. Parse the date from today_string.

# %%
print(today_string)
# Out:
# 2021-08-08

# %%
4. List the files in your current directory

# %%
import os
arr = os.listdir()
print(arr)
# Out:
# ['.ipynb_checkpoints', 'Assignment_1.ipynb', 'Assignment_10.ipynb', 'Assignment_11.ipynb', 'Assignment_12.ipynb', 'Assignment_13.ipynb', 'Assignment_14.ipynb', 'Assignment_15.ipynb', 'Assignment_16.ipynb', 'Assignment_17.ipynb', 'Assignment_18.ipynb', 'Assignment_19.ipynb', 'Assignment_2.ipynb', 'Assignment_20.ipynb', 'Assignment_21.ipynb', 'Assignment_3.ipynb', 'Assignment_4.ipynb', 'Assignment_5.ipynb', 'Assignment_6.ipynb', 'Assignment_7.ipynb', 'Assignment_8.ipynb', 'Assignment_9.ipynb', 'book.db', 'books.csv', 'drawing.png', 'file.csv', 'image.jpg', 'image2.png', 'line.png', 'test.db', 'test.txt', 'today.txt', 'zoo.py', '__pycache__']

# %%
5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
os.path.abspath(os.path.join(path, os.pardir))
# Out:
# 'C:\\Users\\Saurabh\\anaconda3\\Python\\I-neuron\\Untitled Folder'

# %%
import os
arr = os.listdir(os.pardir)
print(arr)
# Out:
# ['.ipynb_checkpoints', 'New folder', 'New folder (2)', 'New folder (3)', 'New folder (4)', 'Python Basic Assignment']

# %%
6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing

import random

import time

def worker(name): 
    print(f'Started worker {name}')
    worker_time = random.choice(range(1, 5))
    time.sleep(worker_time)
    print(f'{name} worker finished in {worker_time} seconds')
if __name__ == '__main__':
    for i in range(5):
        process = multiprocessing.Process(target=worker,args=(i,))
        process.start()
        process.join()

# %%
Code is working ok in VS code


Windows PowerShell
Copyright (C) Microsoft Corporation. All rights reserved.

Try the new cross-platform PowerShell https://aka.ms/pscore6

PS C:\Users\Saurabh> conda activate base
PS C:\Users\Saurabh> & C:/Users/Saurabh/anaconda3/python.exe "c:/Users/Saurabh/Desktop/import socket.py"
Started worker 0
0 worker finished in 2 seconds
Started worker 1
1 worker finished in 3 seconds
Started worker 2
2 worker finished in 4 seconds
Started worker 3
3 worker finished in 2 seconds
Started worker 4
4 worker finished in 1 seconds
PS C:\Users\Saurabh>

# %%
7. Create a date object of your day of birth.

# %%
import datetime

x = datetime.date(1996, 9, 25)

print(x)
# Out:
# 1996-09-25

# %%
8. What day of the week was your day of birth?

# %%
x = datetime.date(1996, 9, 25).weekday()
print(x)
# Out:
# 2

# %%
9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import datetime
from datetime import timedelta

# %%
x = datetime.date(1996, 9, 25)

# %%
y=x+timedelta(days=10000)
print(y)
# Out:
# 2024-02-11
