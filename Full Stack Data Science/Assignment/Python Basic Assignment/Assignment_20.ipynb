# %%
1. Set the variable test1 to the string 'This is a test of the emergency text system,' and save test1 to a file named test.txt.

# %%
test1='This is a test of the emergency text system,'

# %%
f = open("test.txt", "w")
f.write(test1)
f.close()

# %%
2. Read the contents of the file test.txt into the variable test2. Is there a difference between test 1 and test 2?

# %%
f = open("test.txt", "r")
print(f.read())
# Out:
# This is a test of the emergency text system,

# %%
3. Create a CSV file called books.csv by using these lines:
title,author,year
The Weirdstone of Brisingamen,Alan Garner,1960
Perdido Street Station,China Miéville,2000
Thud!,Terry Pratchett,2005
The Spellman Files,Lisa Lutz,2007
Small Gods,Terry Pratchett,1992

# %%
fields=['title','author','year']

a=[['The Weirdstone of Brisingamen','Alan Garner',1960],
['Perdido Street Station','China Miéville',2000],
['Thud!','Terry Pratchett',2005],
['The Spellman Files','Lisa Lutz',2007],
['Small Gods','Terry Pratchett',1992]]

import csv
filename = "books.csv"

with open(filename, 'w') as csvfile: 

    csvwriter = csv.writer(csvfile) 

    csvwriter.writerow(fields) 

    csvwriter.writerows(a)

# %%
4. Use the sqlite3 module to create a SQLite database called books.db, and a table called books with these fields: title (text), author (text), and year (integer).

# %%
import sqlite3

conn = sqlite3.connect('book.db')


conn.execute('''CREATE TABLE Book1
         (Title Text     NOT NULL,
         Author           TEXT    NOT NULL,
         Year            INT     NOT NULL);''')

# %%
5. Read books.csv and insert its data into the book table.

# %%
import pandas as pd
import sqlite3

df= pd.read_csv('books.csv',encoding='latin-1')
conn = sqlite3.connect('book.db')
for index, row in df.iterrows():
    conn.execute('insert into Book1 values (?,?,?)', (row['title'],row['author'],row['year']))
conn.commit()

# %%
6. Select and print the title column from the book table in alphabetical order.

# %%
cursor = conn.execute("SELECT Title, Author, Year from Book order by Title")

# %%
for row in cursor:
    print( row[0])
# Out:
# Perdido Street Station
# Small Gods
# The Spellman Files
# The Weirdstone of Brisingamen
# Thud!

# %%
7. From the book table, select and print all columns in the order of publication.

# %%
cursor = conn.execute("SELECT Title, Author, Year from Book order by Year")
for row in cursor:
    print( row)
# Out:
# ('The Weirdstone of Brisingamen', 'Alan Garner', 1960)
# ('Small Gods', 'Terry Pratchett', 1992)
# ('Perdido Street Station', 'China Miéville', 2000)
# ('Thud!', 'Terry Pratchett', 2005)
# ('The Spellman Files', 'Lisa Lutz', 2007)

# %%
8. Use the sqlalchemy module to connect to the sqlite3 database books.db that you just made in exercise 6.

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///book.db', echo = True)

# %%
9. Install the Redis server and the Python redis library (pip install redis) on your computer. Create a Redis hash called test with the fields count (1) and name ('Fester Bestertester'). Print all the fields for test.

# %%
# !pip install redis

# %%
import redis

redisClient = redis.Redis()

# %%
redisClient.hset('test', {'count': 1, 'name': 'Fester Bestertester'})
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\redis\connection.py in connect(self)
#     558         try:
# --> 559             sock = self._connect()
#     560         except socket.timeout:
#
# ~\anaconda3\lib\site-packages\redis\connection.py in _connect(self)
#     614         if err is not None:
# --> 615             raise err
#     616         raise socket.error("socket.getaddrinfo returned an empty list")
#
# ~\anaconda3\lib\site-packages\redis\connection.py in _connect(self)
#     602                 # connect
# --> 603                 sock.connect(socket_address)
#     604
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
10. Increment the count field of test and print it.

# %%
redisClient.hincrby('test', 'count', 3)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\redis\connection.py in connect(self)
#     558         try:
# --> 559             sock = self._connect()
#     560         except socket.timeout:
#
# ~\anaconda3\lib\site-packages\redis\connection.py in _connect(self)
#     614         if err is not None:
# --> 615             raise err
#     616         raise socket.error("socket.getaddrinfo returned an empty list")
#
# ~\anaconda3\lib\site-packages\redis\connection.py in _connect(self)
#     602                 # connect
# --> 603                 sock.connect(socket_address)
#     604
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# ...
