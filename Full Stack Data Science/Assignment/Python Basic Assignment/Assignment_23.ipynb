# %%
1. What is the result of the code, and why?
def func(a, b=6, c=8):
    print(a, b, c)
func(1, 2)


3 parameters are passed b and c has default value if no value is passed for them this dafault value will be used
for b 2 is passed that's why it prints 2

# %%
def func(a, b=6, c=8):
    print(a, b, c)
func(1, 2)
# Out:
# 1 2 8

# %%
2. What is the result of this code, and why?
def func(a, b, c=5):
    print(a, b, c)
func(1, c=3, b=2)


In this we have declared c and b to have values 3 and 2 so order doesn't matter while passing the parameter

# %%
def func(a, b, c=5):
    print(a, b, c)
func(1, c=3, b=2)
# Out:
# 1 2 3

# %%
3. How about this code: what is its result, and why?
def func(a, *pargs):
    print(a, pargs)
func(1, 2, 3)

*pargs we can pass and number of parameter

# %%
def func(a, *pargs):
    print(a, pargs)
func(1, 2, 3)
# Out:
# 1 (2, 3)

# %%
4. What does this code print, and why?
def func(a, **kargs):
    print(a, kargs)
func(a=1, c=3, b=2)


**kargs is used to pass dictionary arguments to function

# %%
def func(a, **kargs):
    print(a, kargs)
func(a=1, c=3, b=2)
# Out:
# 1 {'c': 3, 'b': 2}

# %%
5. What gets printed by this, and explain?
def func(a, b, c=8, d=5):
    print(a, b, c, d)
func(1, *(5, 6))

1 is passed for a 
*(5,6) got assigned to b and c
d by default has 5

# %%
def func(a, b, c=8, d=5):
    print(a, b, c, d)
func(1, *(5, 6))
# Out:
# 1 5 6 5

# %%
6. what is the result of this, and explain?
def func(a, b, c):
    a = 2; b[0] = 'x'; c['a'] = 'y'
l=1; m=[1]; n={'a':0}
func(l, m, n)
l, m, n

# %%
def func(a, b, c):
    a = 2; b[0] = 'x'; c['a'] = 'y'
l=1; m=[1]; n={'a':0}
func(l, m, n)
l, m, n


l is assigned global value of l
m[0] got value of x
and n key a gt value y
# Out:
# (1, ['x'], {'a': 'y'})
