# %%
1) . What is the difference between enclosing a list comprehension in square brackets and parentheses?

square bracket is used for list
parentheses is ude for dictionary

# %%
2) What is the relationship between generators and iterators?

genrator genrate object one by one
iterator return it one by one

# %%
3) What are the signs that a function is a generator function?

it will have yeild statement

# %%
What is the purpose of a yield statement?

like the return statement in a function instead of returning the output, it returns a generator that can be iterated upon

# %%
5) What is the relationship between map calls and list comprehensions? Make a comparison and contrast between the two.

list comprehensions are easier to write compare to map
for map we have to define function or a lambda functiom
map retur a map object not list

# %%
lst = [1,2,3,4,5]

x = [i * 2 for i in lst ] 
print(x)
# Out:
# [2, 4, 6, 8, 10]

# %%
def num (n) :
    return n * 2
x = map(num, lst) 
print(x)
