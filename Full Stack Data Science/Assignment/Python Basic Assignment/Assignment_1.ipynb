# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# Answer
#
# Value-'hello',-87.8,6
# Expression-*,-,+,/

# %% [raw]
# 2. What is the difference between string and variable?
#
# Answer
#
# String- It is a datatype
# Variable- It is location in memory where data/values is stored

# %% [raw]
# 3. Describe three different data types.
#
# Answer
#
# Bool- True/ False values
# int- All Integer number (-9,-5,0,7,6)
# Float- Fractional number (1.55, 5.3, 7.12, 0.25)

# %% [raw]
# 4. What is an expression made up of? What do all expressions do?
#
# Answer
#
# Expressions are made of values, variable operator and functions
# Python will evaluate this expression to give some results

# %% [raw]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Answer
#
# assignment statements don't return any values
# expression when executed return some value

# %%
# example of assignment statements
spam=10

# %%
# example of Expression
print(spam)
# Out:
# 10

# %% [raw]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Answer
#
# It will store 22 in variable and in next line add 1 in 22 and return 23

# %%
bacon = 22
bacon + 1
# Out:
# 23

# %% [raw]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Answer
#
# concat opration will be performed it both the line
# 1. 'spam' will be concated to 'spamspam'
# 2. 'spam' will be conceted 3 times

# %%
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam' * 3
# Out:
# 'spamspamspam'

# %% [raw]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Answer
#
# Variable name can't be start with a number

# %% [raw]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# int(), float(), str()

# %% [raw]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Answer
#
# We cannot add string and integer in python
# To run this we need to convert 99 to string

# %%
'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
