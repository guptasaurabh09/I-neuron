# %%
1. What is the relationship between def statements and lambda expressions ?

lambda  and def is same only lambda we doesn;t need to give a name to function

# %%
2. What is the benefit of lambda?

1. reduce line of code
2. define and can be use there only

# %%
3. Compare and contrast map, filter, and reduce.

map- function applies a given function to all the itmes in a list and returns the result
filter- function is used to filter a given iterable using another function that defines the filtering logic
reduce- function performs a repetitive operation over the pairs of the elements in the list.

# %%
4. What are function annotations, and how are they used?

annotation are just there to tell what value should be passed or return 
it has no effect on actual code

# %%
5. What are recursive functions, and how are they used?

recursive function call itself
they can be used by calling the function inside a function

# %%
6. What are some general design guidelines for coding functions?

1. Use 4-space indentation and no tabs

# %%
7. Name three or more ways that functions can communicate results to a caller.

print()
return
