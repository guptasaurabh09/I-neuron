# %%
1. Why are functions advantageous to have in your programs?

Using fuction we can reuse a piece of code

# %%
def func(a):
    return a+1
print(func(10))
print(func(100))
# Out:
# 11
# 101

# %%
2. When does the code in a function run: when it's specified or when it's called?

The code will run when function is called

# %%
def func(a):
    return a+1

# %%
func(10)
# Out:
# 11

# %%
3. What statement creates a function?

def keyword is used to create functions

# %%
4. What is the difference between a function and a function call?

Function is when we define function and fuction call is when we used that fuction

# %%
5. How many global scopes are there in a Python program? How many local scopes?

There can be only 1 global scope
We can have any number of local scope every time we call a function new local scope is created

# %%
6. What happens to variables in a local scope when the function call returns?

The local variable will be destroyed once exceution is completed

# %%
def fun():
    a=10
    print(a)
fun()

# if we try to print a after function is excuted it will throw an error because variable is destroyed
print(a)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0a478fbab1d5> in <module>
#       5
#       6 # if we try to print a after function is excuted it will throw an error because variable is destroyed
# ----> 7 print(a)
#
# NameError: name 'a' is not defined

# %%
8. If a function does not have a return statement, what is the return value of a call to that function?

It will have None return value

# %%
def fun():
    a=10

type(fun())
# Out:
# NoneType

# %%
9. How do you make a function variable refer to the global variable?

We can you global variable inside a functiom

# %%
def fun():
    global a
    a=10

# %%
10. What is the data type of None?

It has no Datatype

# %%
type(None)
# Out:
# NoneType

# %%
11. What does the sentence import areallyourpetsnamederic do?

import areallyourpetsnamederic will allow our program to access  module from areallyourpetsnamederic

# %%
12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

import spam as sp

sp.bacon()

# %%
13. What can you do to save a programme from crashing if it encounters an error?

exception handling can be used

# %%
14. What is the purpose of the try clause? What is the purpose of the except clause?

We used try to define a code that can throw error and exception is to handle that error
