# %%
Q1. Define the relationship between a class and its instances. Is it a one-to-one or a one-to-many partnership, for example?

class is a code template and object is to call the methods of class
we can has many object of a single class
car is a class audi bmw is objects

# %%
Q2. What kind of data is held only in an instance?

it held data of object to the class

# %%
class demo:
    pass
d=demo()
type(d)
# Out:
# __main__.demo

# %%
Q3. What kind of knowledge is stored in a class?

methods and variables

# %%
Q4. What exactly is a method, and how is it different from a regular function?

you need an object to call a method
function can be call diretly

# %%
Q5. Is inheritance supported in Python, and if so, what is the syntax?

# %%
class A:
    pass
class B(A):
    pass

# %%
Q6. How much encapsulation (making instance or class variables private) does Python support?

# %%
Python dosn't have any keyword for private

__varaible you can declare a private variable like this

# %%
Q7. How do you distinguish between a class variable and an instance variable?

# %%
Q8. When, if ever, can self be included in a class's method definitions?

self is define as this instance of class 
we need to include it when dealing with multiple objects

# %%
Q9. What is the difference between the _ _add_ _ and the _ _radd_ _ methods?

if we used overload add like obj+5 it will impletemnet it as obj__add__(5) but vice versa is not possible
5__add__(obj) itwill throw error
now if there is __radd__ it will convert 5__add__(obj) to onj__add__(5)

# %%
Q10. When is it necessary to use a reflection method? When do you not need it, even though you support the operation in question?

# %%
Q11. What is the _ _iadd_ _ method called?

inplace operation
a+=b

# %%
Q12. Is the _ _init_ _ method inherited by subclasses? What do you do if you need to customize its behavior within a subclass

yes it can be inherited by sub class
we can override it
