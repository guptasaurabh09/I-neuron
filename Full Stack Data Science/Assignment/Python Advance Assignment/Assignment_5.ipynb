# %%
Q1. What is the meaning of multiple inheritance?

When a class is derived from more than one base class it is called multiple Inheritance

# %%
Q2. What is the concept of delegation?

Inharitance works well when we have 'is a relationshp'
but when we don't have that delegation can be used
it will duplicate code/method in the compostion

# %%
Q3. What is the concept of composition?

When classes have 'has a relationship' we cannot use inheritance here we use composition to call the method

# %%
class Microwave:
    def __init__(self):
        pass

    def heat_up_food(self):
        print("Food is being microwaved")

class Dishwasher:
    def __init__(self):
        pass

    def wash_dishes(self):
        print("Dishwasher starting")

class Kitchen:
    def __init__(self):
        self.microwave = Microwave()
        self.dishwasher = Dishwasher()

    def  heat_up_food(self):
        self.microwave.heat_up_food()

    def wash_dishes(self):
        self.dishwasher.wash_dishes()


kitchen = Kitchen()
kitchen.heat_up_food()
kitchen.wash_dishes()
# Out:
# Food is being microwaved
# Dishwasher starting

# %%
Q4. What are bound methods and how do we use them?

in bound method  the instance of the class is the first argument

obj.func(arg) is translated by python as A.func(obj, arg)

# %%
class A:
  
    def func(self, arg):
        self.arg = arg
        print("Value of arg = ", arg)

obj = A()  

print(obj.func)
# Out:
# <bound method A.func of <__main__.A object at 0x0000021F85AD9DC0>>

# %%
Q5. What is the purpose of pseudoprivate attributes?

Python has no concept private class 
hence pseudoprivate is use to tell user which method\var is private
