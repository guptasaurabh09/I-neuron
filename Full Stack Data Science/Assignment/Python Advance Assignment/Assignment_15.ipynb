# %%
1.	What are the new features added in Python 3.8 version?

https://docs.python.org/3/whatsnew/3.8.html

# %%
2.	What is monkey patching in Python?

the term monkey patch refers to dynamic (or run-time) modifications of a class or module
we can actually change the behavior of code at run-tim

# %%
3.	What is the difference between a shallow copy and deep copy?

# %%
4.	What is the maximum possible length of an identifier?

79 characters

# %%
5.	What is generator comprehension?

 a single-line specification for defining a generator in Python

# %%
gen=(i for i in range(5))

# %%
next(gen)
# Out:
# 0

# %%
next(gen)
# Out:
# 1
