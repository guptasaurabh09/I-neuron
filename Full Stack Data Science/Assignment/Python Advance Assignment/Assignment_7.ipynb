# %%
Q1. What is the purpose of the try statement?

When we have a code that can throw some error we right that in try block

# %%
Q2. What are the two most popular try statement variations?

try except
try except else

# %%
Q3. What is the purpose of the raise statement?

raise statement is used to raise an exception

# %%
Q4. What does the assert statement do, and what other statement is it like?

assert statement continue the execution if the condition is True. Ifassert condition is False then it raises the AssertionError exception

if raise is like it

# %%
Q5. What is the purpose of the with/as argument, and what other statement is it like?

It make it easy to read

with open('hello.txt', 'w') as file:
    
Other option

file = open('hello.txt')
