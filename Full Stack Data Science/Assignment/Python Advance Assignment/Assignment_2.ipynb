# %%
Q1. What is the relationship between classes and modules?

a class is used to define a blueprint for a given object
a module is used to reuse a given piece of code inside another program

# %%
Q2. How do you make instances and classes?

variable_name= class_name()

# %%
Q3. Where and how should be class attributes created?

class attribute is created inside class 
it is define for class not for a particular object

# %%
class demo:
    x = 0   # attribute
  
    def Something(self):
        pass

# %%
Q4. Where and how are instance attributes created?

it is variable define for only 1 object and can be access by that object only
define inside __init__

# %%
Q5. What does the term "self" in a Python class mean?

self refer to the current instance of the class

# %%
Q6. How does a Python class handle operator overloading?

Operator Overloading means giving extended meaning beyond their predefined operational meaninng

+ can use to add str and int
but we can use it to add two class object by overloading it

# %%
Q7. When do you consider allowing operator overloading of your classes?

When allow operator overloading when the predefine operator is not sutable for our requirment and we can modify it so that it can be used

# %%
Q8. What is the most popular form of operator overloading?

Addition (+) operator
+ can use to add str and int
but we can use it to add two class object by overloading it

# %%
Q9. What are the two most important concepts to grasp in order to comprehend Python OOP code?

1. class instance
2. inheritance
