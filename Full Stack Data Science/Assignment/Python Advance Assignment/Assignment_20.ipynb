# %%
1. Compare and contrast the float and Decimal classes' benefits and drawbacks.

with flost we can have an error 
Decimal don't reply on binry fraction so it will not give error

# %%
a = 10
b = a / 77
c = b * 77
print(f"{a:.20f}") 
print(f"{c:.20f}")
# Out:
# 10.00000000000000000000
# 9.99999999999999822364

# %%
import decimal

a = decimal.Decimal(10)
b = a / 77
c = b * 77
print(f"{a:.20f}") 
print(f"{c:.20f}")
# Out:
# 10.00000000000000000000
# 10.00000000000000000000

# %%
2. Decimal('1.200') and Decimal('1.2') are two objects to consider. In what sense are these the same object? Are these just two ways of representing the exact same value, or do they correspond to different internal states?

# %%
a = decimal.Decimal('1.200')
b = decimal.Decimal('1.2')
print(a)
print(b)
# Out:
# 1.200
# 1.2

# %%
3. What happens if the equality of Decimal('1.200') and Decimal('1.2') is checked?
# Out:
# Object `checked` not found.

# %%
3. What happens if the equality of Decimal('1.200') and Decimal('1.2') is checked

# %%
a==b
# Out:
# True

# %%
4. Why is it preferable to start a Decimal object with a string rather than a floating-point value?

Converting straight from a float causes our Decimal object to inherit all of the imprecision that we were trying to avoid in the first place.

# %%
a = decimal.Decimal('1.2')
b = decimal.Decimal(1.2)
print(a)
print(b)
# Out:
# 1.2
# 1.1999999999999999555910790149937383830547332763671875

# %%
5. In an arithmetic phrase, how simple is it to combine Decimal objects with integers?

we can add int with decimal objec 
it will return a decimal object

# %%
a+5
# Out:
# Decimal('6.2')

# %%
6. Can Decimal objects and floating-point values be combined easily?

NO cannot be combine directly
# Out:
# Object `easily` not found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-279330c784a5> in <module>
#       1 get_ipython().run_line_magic('pinfo', 'easily')
#       2
# ----> 3 a+1.25
#
# TypeError: unsupported operand type(s) for +: 'decimal.Decimal' and 'float'

# %%
a+1.25
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-5156b22fccef> in <module>
# ----> 1 a+1.25
#
# TypeError: unsupported operand type(s) for +: 'decimal.Decimal' and 'float'

# %%
7. Using the Fraction class but not the Decimal class, give an example of a quantity that can be expressed with absolute precision.

# %%
from fractions import Fraction
  
print (Fraction(1.2))
# Out:
# 5404319552844595/4503599627370496

# %%
5404319552844595/4503599627370496
# Out:
# 1.2

# %%
 Describe a quantity that can be accurately expressed by the Decimal or Fraction classes but not by a floating-point value.

# %%
x=10
a = decimal.Decimal(10)
b = a / 77
c = x/77
print (Fraction(x/77))
print(b) 
print(c)
# Out:
# 2339532273958699/18014398509481984
# 0.1298701298701298701298701299
# 0.12987012987012986

# %%
2339532273958699/18014398509481984
# Out:
# 0.12987012987012986

# %%
Q9.Consider the following two fraction objects: Fraction(1, 2) and Fraction(1, 2). (5, 10). Is the internal state of these two objects the same? Why do you think that is?

# %%
Fraction(1, 2)
# Out:
# Fraction(1, 2)

# %%
Fraction(5, 10)
# Out:
# Fraction(1, 2)

# %%
Q10. How do the Fraction class and the integer type (int) relate to each other? Containment or inheritance?
