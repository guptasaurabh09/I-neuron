# %%
Q1. What is the purpose of Python's OOP?

OOPs is used to make code standard and resusable that help when we writ big codes

# %%
Q2. Where does an inheritance search look for an attribute?

Python searches the namespace tree at and above object , for the first attr it can find.
Because lower definitions in the tree override higher ones, inheritance forms the basis of specialization

# %%
Q3. How do you distinguish between a class object and an instance object?

Class object is created from Class name it can be only one
Instance object is when we create diff instance of class

# %%
class Demo:
    x=10

# Class object

print(Demo.x)

# instance object

d=Demo()
# Out:
# 10

# %%
Q4. What makes the first argument in a class’s method function special?

it always a reference to the current instance of the class 
mostly denoted by self

# %%
Q5. What is the purpose of the __init__ method?

It is like a constructor in java language
it automatically run when instance objject is created

# %%
Q6. What is the process for creating a class instance?

We can create a class instance so that we can reuse the code of class for different values

Like Class car can have audi BMW instance

# %%
Q7. What is the process for creating a class?

To write a code that can be reuse by creating different instance object

# %%
Q8. How would you define the superclasses of a class?

super() allows you to child classes that easily extend the function of parent classes without implementing their function again
