# %%
Q1. What is the difference between __getattr__ and __getattribute__?

Python will call __getattr__ method whenever you request an attribute that hasn't already been defined.

 __getattribute__ python invokes this method for every attribute regardless whether it exists or not

# %%
Q2. What is the difference between properties and descriptors?

descriptor are classes that allow you to do managed properties in another class

property function gives us a handy way to implement a simple descriptor without defining a separate class.
Rather than create a complete class definition, we can write getter and setter method functions, and then bind these functions to an attribute name.

# %%
Q3. What are the key differences in functionality between __getattr__ and __getattribute__, as well as properties and descriptors?



Python will call __getattr__ method whenever you request an attribute that hasn't already been defined.

 __getattribute__ python invokes this method for every attribute regardless whether it exists or not
    
descriptor are classes that allow you to do managed properties in another class

property function gives us a handy way to implement a simple descriptor without defining a separate class.
Rather than create a complete class definition, we can write getter and setter method functions, and then bind these functions to an attribute name.
